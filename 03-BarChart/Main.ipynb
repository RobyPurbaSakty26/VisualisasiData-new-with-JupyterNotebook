# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print (matplotlib.__version__)
print(np.__version__)
# Out:
# 3.5.1
# 1.22.2

# %% [markdown]
# ## Seimple bar plot

# %%
data = [25,45,55,125,225]
kategori = ['A','B','C','D','D']

# %%
plt.bar(kategori, data)
plt.grid()

plt.xlabel('Kategori')
plt.ylabel('Jumlah')



plt.show()

# %% [markdown]
# ## Pengaturan grid dan color

# %%
plt.bar(kategori, 
    data,
    color='blue',
    alpha=0.75)
plt.grid(
    linestyle='--', 
    linewidth=2, 
    axis='x', # pilih both x, y both
    alpha=0.70)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')



plt.show()

# %% [markdown]
# ## Harisontal Bar Plot

# %%
# plt.barh(kategori, data)
plt.barh(kategori[::-1], data[::-1])

plt.grid(
    linestyle='--',
    linewidth=1,
    axis='x',
    alpha=0.75
)

plt.xlabel('julah')
plt.ylabel('Kategori')
plt.title('contoh horizontal barplot')

plt.show()

# %% [markdown]
# ## stake bar plot

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, data1, label='Data 1')

# plt.bar(kategori, data2, label='Data2')
# digunakan untuk menyimpan layer  data 1 ke bawah
plt.bar(kategori, data2, label='Data 2', bottom=data1)

plt.legend()

plt.grid(
    linestyle='--',
    linewidth=1,
    axis='y',
    alpha=0.75
)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked bar plot')

plt.show()
